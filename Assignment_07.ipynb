# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt 
from skimage import img_as_uint
from skimage.io import imshow, imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray

# %%
array=np.array([[255,0],[0,0]])
imshow(array,cmap='gray')

# %%
array=np.array([[100,0],[150,200]])
imshow(array,cmap = 'gray')

# %%
array1=np.array([[255,0,0],[0,255,0],[0,0,255]])
imshow(array1,cmap='gray')

# %%
array_2 = np.array([[255, 0, 255],
[0, 255, 0],
[255, 0, 255]])
imshow(array_2, cmap = 'gray')

# %%
array_spectrum = np.array([np.arange(0,255,17),
np.arange(255,0,-17),
np.arange(255,0,-17)])
fig,ax=plt.subplots(1, 2,figsize=(12,4))
ax[0].imshow(array_spectrum, cmap= 'gray')
ax[0].set_title('ArangeGeneration')
ax[1].imshow(array_spectrum.T, cmap= 'gray')
ax[1].set_title('Transpose Generation')
# Out:
# Text(0.5, 1.0, 'Transpose Generation')

# %%
array_colors = np.array([[[200, 100, 59],
[150, 255, 100],
[100, , 255]]])
imshow(array_colors);

# %%
img1 =imread('img.png')
imshow(img1)

# %%
img1.shape
# Out:
# (178, 283, 3)

# %%
fig, ax = plt.subplots(1, 3,
figsize=(6,4),
sharey= True)

ax[0].imshow(img1[:, 0:130])
ax[0].set_title('First Split')

ax[1].imshow(img1[:, 130:260])
ax[1].set_title('Second Split')

ax[2].imshow(img1[:, 260:390])
ax[2].set_title('Third Split');

# %%
imshow(img1[95:250, 130:275])

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4), sharey =True)
ax[0].imshow(img1[:,:,0], cmap='Reds')
ax[0].set_title('Red')
ax[1].imshow(img1[:,:,1],cmap='Greens')
ax[1].set_title('Green')
ax[2].imshow(img1[:,:,2],cmap='Blues')
ax[2].set_title('Blue')
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
img1_hsv = rgb2hsv(img1)
fig, ax = plt.subplots(1, 3, figsize=(12,4), sharey = True)
ax[0].imshow(img1_hsv[:,:,0], cmap='hsv')
ax[0].set_title('Hue')
ax[1].imshow(img1_hsv[:,:,1],cmap='gray')
ax[1].set_title('Saturation')
ax[2].imshow(img1_hsv[:,:,2], cmap='gray')
ax[2].set_title('Value');

# %%
doggo_gray = rgb2gray(img1)
fig, ax =plt.subplots(1, 5, figsize=(17,6), sharey = True)
ax[0].imshow(doggo_gray, cmap = 'gray')
ax[0].set_title('GrayscaleOriginal')
ax[1].imshow(img_as_uint(doggo_gray >0.25),cmap = 'gray')
ax[1].set_title('Greater than0.25')
ax[2].imshow(img_as_uint(doggo_gray >0.50),cmap = 'gray')
ax[2].set_title('Greater than0.50')
ax[3].imshow(img_as_uint(doggo_gray >0.75),cmap = 'gray')
ax[3].set_title('Greater than0.75')
ax[4].imshow(img_as_uint(doggo_gray >np.mean(doggo_gray)),cmap = 'gray')
ax[4].set_title('Greater than Mean');
